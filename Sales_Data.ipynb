# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sales_data = pd.read_csv('/content/sales_data.csv')

# %%
df_sales_data.head()
# Out:
#    customer_id product  sales_amount   sale_date
# 0           31       g    449.167593  2022-06-09
# 1           79       b    533.140152  2022-12-03
# 2           51       i    557.437773  2022-08-27
# 3           14       e    553.331433  2022-08-01
# 4           67       a    524.837592  2022-10-06

# %%
df_sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1000 non-null   int64
#  1   product       1000 non-null   object
#  2   sales_amount  1000 non-null   float64
#  3   sale_date     1000 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 31.4+ KB

# %%
df_sales_data.describe()
# Out:
#        customer_id  sales_amount
# count  1000.000000   1000.000000
# mean     51.399000    496.815365
# std      28.818194    101.371208
# min       1.000000    117.480723
# 25%      26.000000    428.080091
# 50%      52.000000    501.189260
# 75%      76.000000    562.610904
# max     100.000000    885.175797

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_sales_data['sales_amount'], bins=20, kde=True
             , color='turquoise')
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()
